# %%
from astropy.table import Table, vstack
from astropy.coordinates import SkyCoord
import astropy.units as u
from collections import Counter
import numpy as np
from astropy.wcs import WCS
from matplotlib.colors import LogNorm
from astropy.io import fits
from radio_beam import Beam
import matplotlib.pyplot as plt

# %%
ACES_cat_path = 'aces_zooniverse_catalog_with_SI.fits'
ACES_cat = Table.read(ACES_cat_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ACES_cat_path = 'aces_zooniverse_catalog_with_SI.fits'
# ----> 2 ACES_cat = Table.read(ACES_cat_path)
#
# NameError: name 'Table' is not defined

# %%
ACES_cat
# Out:
# <Table length=1693>
# index    area_ellipse    ... SI_cmzoom_aces cmzoom_lower_limit?
#            arcsec2       ...
# int64      float64       ...    float64             bool
# ----- ------------------ ... -------------- -------------------
#   278  5.583657781682184 ...             --               False
#   344 1.6048503198059558 ...             --               False
#   388   7.64507806585681 ...             --               False
#   478  8.965680321187095 ...             --               False
#   489  2.992883239634674 ...             --               False
#   514  8.188439269129121 ...             --               False
#   565 1.9885802505090069 ...             --               False
#   577 0.5978805160962057 ...             --               False
#   585 1.3451030795955536 ...             --               False
#   ...                ... ...            ...                 ...
# 23892  1.980503521762684 ...             --               False
# 23919 1.1119469505239812 ...             --               False
# 23931  2.333213915293389 ...             --               False
# 23942 3.6323272151066597 ...             --               False
# 24013 1.6531891264997072 ...             --               False
# 24097   13.8805249614599 ...             --               False
# 24239 3.1742672157705694 ...             --               False
# 24267  5.271642903474896 ...             --               False
# 24335  3.825468005152429 ...             --               False
